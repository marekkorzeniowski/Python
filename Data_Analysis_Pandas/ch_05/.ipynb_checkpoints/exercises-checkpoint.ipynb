# %%
import pandas as pd

fb = pd.read_csv('data/fb_stock_prices_2018.csv', index_col='date', parse_dates=['date'])

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2018-01-02 to 2018-12-31
# Data columns (total 5 columns):
# open      251 non-null float64
# high      251 non-null float64
# low       251 non-null float64
# close     251 non-null float64
# volume    251 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 11.8 KB

# %%
fb.assign(
    rolling_close = lambda x: x.close.rolling('20D').min()
).plot(
    y="rolling_close",
    figsize=(10,5)
)

# %%
fb.plot(
    y="close",
    figsize=(10,5)
)

# %%
fb.plot(
    y='high',
    kind='hist'
)

# %%
ax = fb.assign(
    change = lambda x: x.open - x.close
).plot(kind='hist',
        y='change',
      density=True,
      alpha = 0.5)

(fb.open - fb.close).plot(
    ax=ax, kind='kde'
)

# %%
qu = pd.read_csv('data/earthquakes.csv')

# %%
qu.head()
# Out:
#     mag magType           time                  place  tsunami parsed_place
# 0  1.35      ml  1539475168010  9km NE of Aguanga, CA        0   California
# 1  1.29      ml  1539475129610  9km NE of Aguanga, CA        0   California
# 2  3.42      ml  1539475062610  8km NE of Aguanga, CA        0   California
# 3  0.44      ml  1539474978070  9km NE of Aguanga, CA        0   California
# 4  2.16      md  1539474716050  10km NW of Avenal, CA        0   California

# %%
qu.query("parsed_place =='Indonesia'").loc[:,['magType','mag']]
# Out:
#      magType  mag
# 9         mb  4.7
# 13        mb  4.5
# 180      mww  5.2
# 421       mb  4.7
# 660       mb  4.4
# 757      mww  5.6
# 846       mb  4.3
# 862      mww  6.0
# 877       mb  4.9
# 1052      mb  4.6
# 1226      mb  4.6
# 1392      mb  4.6
# 1406      mb  5.1
# 1408      mb  4.6
# 1682      mb  4.4
# 1698     mww  5.1
# 1827      mb  4.4
# 2107      mb  4.4
# 2127      mb  4.2
# 2600      mb  4.5
# 2628      mb  4.4
# 2669      mb  4.4
# 2671      mb  4.7
# 2672      mb  4.6
# 2741      mb  4.5
# 2806      mb  4.6
# 3027      mb  4.2
# 3030      mb  4.3
# 3066      mb  4.5
# 3112      mb  5.3
# ...      ...  ...
# 6310      mb  4.1
# 6367      mb  4.1
# 6383      mb  4.8
# 6538      mb  4.2
# 6666      mb  4.0
# 6910      mb  4.5
# 6969      mb  4.3
# 6981      mb  4.6
# 7230      mb  4.2
# 7448      mb  4.6
# 7569     mww  5.2
# 7578      mb  4.2
# 7684      mb  5.0
# 7709      mb  4.1
# 7813      mb  4.6
# 7846      mb  4.5
# 7897      mb  4.9
# 7979     mwr  4.8
# 8124      mb  4.1
# 8402      mb  4.4
# 8407      mb  4.2
# 8642      mb  4.2
# 8703      mb  4.6
# 8821      mb  4.2
# 8959      mb  4.3
# 9041      mb  4.3
# 9075      mb  4.4
# 9108      mb  4.0
# 9209      mb  4.7
# 9212      mb  4.7
#
# [147 rows x 2 columns]

# %%
qu.loc[(qu.parsed_place == 'Indonesia'), ['magType', 'mag']].groupby('magType').boxplot(figsize=(15,8), subplots=False)

# %%
fb.head()
# Out:
#               open    high       low   close    volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726

# %%
dif= fb.resample('7D').max()

# %%
(dif.high - dif.low).plot(figsize=(12,4))

# %%
fb.resample('1W').agg(
    dict(high='max', low='min')
).assign(
    max_change_weekly=lambda x: x.high - x.low
).max_change_weekly.plot(
    title='Difference between Weekly Maximum High Price\nand Weekly Minimum Low Price of Facebook Stock'
)

# %%
fb.assign(
    prior_close = lambda x: x.close.shift(),
    after_hours = lambda x: x.open - x.prior_close,
    abs_change = lambda x: x.after_hours.abs()
).head()
# Out:
#               open    high       low   close    volume  prior_close  \
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903          NaN
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563       181.42
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896       184.67
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535       184.33
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726       186.85
#
#             after_hours  abs_change
# date
# 2018-01-02          NaN         NaN
# 2018-01-03         0.46        0.46
# 2018-01-04         0.23        0.23
# 2018-01-05         1.26        1.26
# 2018-01-08         0.35        0.35

# %%
daily_change = fb.assign(after_hours = lambda x: x.open - x.close.shift()).after_hours

# %%
daily_change.plot(figsize=(15,4))

# %%
net = daily_change.resample('1M').sum()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,3))

daily_change.plot(
    ax=axes[0]
)

net.plot(
    ax=axes[1],
    kind='bar',
    color = np.where(net >=0, 'g','r'),
    rot=0
)

# %%
net
# Out:
# Jan    -3.3500
# Feb     0.0200
# Mar   -19.3700
# Apr    19.6247
# May    -2.6488
# Jun    -3.6246
# Jul   -35.0750
# Aug     5.5992
# Sep   -14.0150
# Oct     3.0950
# Nov    -8.5100
# Dec    -2.5200
# Name: after_hours, dtype: float64
