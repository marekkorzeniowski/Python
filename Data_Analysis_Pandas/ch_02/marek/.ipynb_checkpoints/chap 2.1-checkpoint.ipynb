# %%
import datetime
import pandas as pd
import requests

yesterday = datetime.date.today() - datetime.timedelta(days=1)
api = 'https://earthquake.usgs.gov/fdsnws/event/1/query'
payload = {
    'format' : 'geojson',
    'starttime' : yesterday - datetime.timedelta(days=26),
    'endtime' : yesterday
}
response = requests.get(api, params=payload)
response.status_code
# Out:
# 200

# %%
earth_quake = response.json()

# %%
earth_quake.keys()
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])

# %%
type(earth_quake['features'])
# Out:
# list

# %%
earth_quake['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 1.73,
#   'place': '29km E of Honaunau-Napoopoo, Hawaii',
#   'time': 1572307153520,
#   'updated': 1572307492950,
#   'tz': -600,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71202341',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv71202341&format=geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'alert': None,
#   'status': 'automatic',
#   'tsunami': 0,
#   'sig': 46,
#   'net': 'hv',
#   'code': '71202341',
#   'ids': ',hv71202341,',
#   'sources': ',hv,',
#   'types': ',geoserve,origin,phase-data,',
#   'nst': 7,
#   'dmin': 0.001799,
#   'rms': 0.09,
#   'gap': 86,
#   'magType': 'ml',
#   'type': 'earthquake',
#   'title': 'M 1.7 - 29km E of Honaunau-Napoopoo, Hawaii'},
#  'geometry': {'type': 'Point',
#   'coordinates': [-155.5820007, 19.4650002, -2.62]},
#  'id': 'hv71202341'}

# %%
data_of_earth_quakes = [quake['properties'] for quake in earth_quake['features']]

# %%
df = pd.DataFrame(data_of_earth_quakes)

# %%
df
# Out:
#       alert  cdi        code  \
# 0      None  NaN    71202341
# 1      None  NaN    61557631
# 2      None  NaN    38921175
# 3      None  NaN    38921167
# 4      None  NaN    38921159
# 5      None  NaN    80369944
# 6      None  NaN    00708803
# 7      None  NaN  019du6mxwl
# 8      None  NaN    70855144
# 9      None  NaN    38921143
# 10     None  NaN    38921135
# 11     None  NaN    2019vdxc
# 12     None  NaN    38921127
# 13     None  NaN    2019vdxb
# 14     None  NaN    00708802
# 15     None  NaN    73298310
# 16     None  NaN    38921111
# 17     None  NaN    38921103
# 18     None  NaN    60347497
# 19     None  NaN    80369929
# 20     None  NaN  019du5j1b6
# 21     None  NaN    38921055
# 22     None  NaN  019du5hpp2
# 23     None  NaN    73298305
# 24     None  NaN    71202121
# 25     None  NaN    73298300
# 26     None  NaN    2019vdtd
# 27     None  NaN    38921039
# 28     None  NaN  019du5d9xg
# 29     None  NaN    38921023
# ...     ...  ...         ...
# ...
