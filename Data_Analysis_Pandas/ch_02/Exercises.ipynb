# %%
import pandas as pd

# %%
path = r'C:\Users\korze\Desktop\Python\Hands-on data analysis\Hands-On-Data-Analysis-with-Pandas-master\ch_02\data\parsed.csv'
df = pd.read_csv(path)
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'parsed_place'],
#       dtype='object')

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# 5      NaN  NaN  2018286011
# 6      NaN  NaN    20280432
# 7      NaN  NaN    73096936
# 8      NaN  NaN    73096931
# 9      NaN  NaN    1000hbtn
# 10     NaN  NaN    37389162
# 11     NaN  NaN  2018286010
# 12     NaN  NaN    37389146
# 13     NaN  NaN    1000hbti
# 14     NaN  NaN    73096921
# 15     NaN  NaN    20280430
# 16     NaN  NaN    73096911
# 17     NaN  NaN  2018286009
# 18     NaN  NaN    20280424
# 19     NaN  NaN    37389114
# 20     NaN  NaN  2018286008
# 21     NaN  NaN    20280421
# 22     NaN  NaN    37389098
# 23     NaN  NaN    37389082
# 24     NaN  NaN    37389074
# 25     NaN  NaN    73096901
# 26     NaN  NaN    20280415
# 27     NaN  NaN    20280412
# 28     NaN  NaN    20280407
# 29     NaN  NaN    73096891
# ...    ...  ...         ...
# 9302   NaN  NaN    73086816
# ...

# %%
df.describe(percentiles=[.25, .5, .95])
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 95%      4.300000     2.678900   40.200000   276.000000     4.400000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# ...

# %%
## 95% quantile in Japan with magType = 'mb'

df_japan = df.loc[(df.parsed_place == 'Japan') & (df.magType == 'mb')]

# %%
df_japan
# Out:
#      alert  cdi      code                                             detail  \
# 67     NaN  NaN  1000hbqa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 713    NaN  NaN  1000hah8  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1124   NaN  NaN  1000h9la  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1309   NaN  NaN  1000h952  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1398   NaN  NaN  1000h8zx  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1422   NaN  1.0  1000h8xg  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1435   NaN  NaN  1000h8vs  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1492   NaN  3.4  1000h8q7  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1563   NaN  NaN  1000h8mj  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1732   NaN  NaN  1000hb41  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1875   NaN  NaN  1000h8c2  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...

# %%
df_japan.mag.quantile(0.95) ## ex1 95% quantile in Japan with magType = 'mb'
# Out:
# 4.9

# %%
earth_Indo_tsu = df.loc[(df.parsed_place == 'Indonesia') & (df.tsunami==1)]
earth_Indo_tot = df.loc[(df.parsed_place == 'Indonesia')]

# %%
len(earth_Indo_tsu.index), len(earth_Indo_tot.index)
# Out:
# (34, 147)

# %%
eq_with_tsunami = len(earth_Indo_tsu.index)/ len(earth_Indo_tot.index) * 100

# %%
df[df.parsed_place.str.endswith('Indonesia')].tsunami.value_counts(normalize=True)
# Out:
# 0    0.768707
# 1    0.231293
# Name: tsunami, dtype: float64

# %%
f"""{df[df.parsed_place.str.endswith('Indonesia')].tsunami.value_counts(normalize=True).loc[1,]:.2%}"""
# Out:
# '23.13%'

# %%
eq_with_tsunami ## ex2 precentage of earth quakes coupled with tsunami in Indonsia
# Out:
# 23.12925170068027

# %%
earth_quakes_NV = df.loc[(df.parsed_place == 'Nevada')]
earth_quakes_NV.describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  681.000000  681.000000  681.000000  6.810000e+02    681.0  681.0
# mean    12.618209    0.151986   10.970631  1.538314e+12      0.0 -480.0
# std      9.866963    0.084662   19.607150  5.965637e+08      0.0    0.0
# ...

# %%
df.shape
# Out:
# (9332, 27)

# %%
df['ring_of_fire'] = df.parsed_place.str.contains(r'|'.join([
    'Bolivia', 'Chile', 'Ecuador', 'Peru', 'Costa Rica', 
    'Guatemala', '^Mexico', 'Japan', 'Philippines',
    'Indonesia', 'New Zealand', 'Antarctic', 'Canada',
    'Fiji', 'Alaska', 'Washington', 'California', 'Russia', 
    'Taiwan', 'Tonga', 'Kermadec Islands'
])) ## solution to ex4

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# 5      NaN  NaN  2018286011
# 6      NaN  NaN    20280432
# 7      NaN  NaN    73096936
# 8      NaN  NaN    73096931
# 9      NaN  NaN    1000hbtn
# 10     NaN  NaN    37389162
# 11     NaN  NaN  2018286010
# 12     NaN  NaN    37389146
# 13     NaN  NaN    1000hbti
# 14     NaN  NaN    73096921
# 15     NaN  NaN    20280430
# 16     NaN  NaN    73096911
# 17     NaN  NaN  2018286009
# 18     NaN  NaN    20280424
# 19     NaN  NaN    37389114
# 20     NaN  NaN  2018286008
# 21     NaN  NaN    20280421
# 22     NaN  NaN    37389098
# 23     NaN  NaN    37389082
# 24     NaN  NaN    37389074
# 25     NaN  NaN    73096901
# 26     NaN  NaN    20280415
# 27     NaN  NaN    20280412
# 28     NaN  NaN    20280407
# 29     NaN  NaN    73096891
# ...    ...  ...         ...
# 9302   NaN  NaN    73086816
# ...

# %%
r'|'.join([
    'Bolivia', 'Chile', 'Ecuador', 'Peru', 'Costa Rica', 
    'Guatemala', '^Mexico', 'Japan', 'Philippines',
    'Indonesia', 'New Zealand', 'Antarctic', 'Canada',
    'Fiji', 'Alaska', 'Washington', 'California', 'Russia', 
    'Taiwan', 'Tonga', 'Kermadec Islands'
])
# Out:
# 'Bolivia|Chile|Ecuador|Peru|Costa Rica|Guatemala|^Mexico|Japan|Philippines|Indonesia|New Zealand|Antarctic|Canada|Fiji|Alaska|Washington|California|Russia|Taiwan|Tonga|Kermadec Islands'

# %%
df.ring_of_fire.value_counts()
# Out:
# True     7188
# False    2144
# Name: ring_of_fire, dtype: int64

# %%
df[(df.tsunami == 1) & (df.ring_of_fire == True)].sum()
# Out:
# cdi             3.590000e+01
# dmin            8.767169e+01
# felt            7.240000e+02
# gap             2.196000e+03
# mag             2.385400e+02
# mmi             1.051600e+02
# nst             1.210000e+02
# rms             4.298000e+01
# sig             2.120600e+04
# time            6.922560e+13
# tsunami         4.500000e+01
# tz              1.374000e+04
# updated         6.923423e+13
# ring_of_fire    4.500000e+01
# dtype: float64

# %%
df.loc[df.ring_of_fire,'tsunami'].sum()
# Out:
# 45

# %%
df.loc?
